# %% [markdown]
# ### exploratory data analysis

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf
from pyspark.sql.types import StringType
from sentence_transformers import SentenceTransformer, util
from sklearn.mixture import GaussianMixture
import tensorflow as tf
import sklearn as skl
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import random
# spark.stop()  # stop any already running
# Out:
# 2024-05-25 18:09:02.099956: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-25 18:09:02.100004: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-25 18:09:02.100705: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-25 18:09:02.104363: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-25 18:09:02.674229: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Initialize a Spark session
spark = SparkSession.builder \
    .appName("Read Cleaned Data") \
    .getOrCreate()


# Read the Parquet file into a DataFrame
s1clean = spark.read.parquet("online_retail_IIs1_clean.parquet/")
s2clean = spark.read.parquet("online_retail_IIs2_clean.parquet/")
# Out:
# 24/05/25 18:09:05 WARN Utils: Your hostname, DESKTOP-25IG4QD resolves to a loopback address: 127.0.1.1; using 172.18.229.145 instead (on interface eth0)
# 24/05/25 18:09:05 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/25 18:09:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### collect product description text

# %%
# Get unique product descriptions
unique_descriptions_s1 = s1clean.select("Description").distinct()
unique_descriptions_s2 = s2clean.select("Description").distinct()

# Combine unique descriptions from both sheets
unique_descriptions = unique_descriptions_s1.union(unique_descriptions_s2).distinct()

# Collect the unique descriptions to a list
unique_descriptions_list = [row['Description'] for row in unique_descriptions.collect()]
print(len(unique_descriptions_list))
for sent in tqdm(unique_descriptions_list):
    sent.replace('  ',' ')
    # sent.strip(',*')
print([unique_descriptions_list[ii] for ii in [random.randint(0,len(unique_descriptions_list)) for _ in range(100)]])
# Out:
# 5211
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5211/5211 [00:00<00:00, 5141500.39it/s]
# ['white murano twist bracelet', 'tea time table cloth', '3 russian doll stacking tins', 'hanging flowers+mirror,blue', 'ivory hanging decoration butterfly', 'watering can single hook pistachio', 'vintage bead cosmetic bag', 'charlie and lola figures tins', '3 rose morris boxed candles', 'ivory wicker heart medium', 'red tea towel classic design', 'trellis flower chopsticks 5', 'green glass tassle bag charm', 'cream hanging heart t-light holder', 'wall art cat and bird', 'pastel blue photo album', 'multi colour silver t-light holder', 'english rose edwardian parasol', 'kings choice small tube matches', 'regency sugar bowl green', 'traditional christmas ribbons', 'white bird garden design mug', 'food container 3 love heart', 'jam making printed', 'frying pan blue polkadot', 'adult apron apple delight', 'pink glass tassle bag charm', 'folding umbrella , black/blue spot', 'pink knitted kids rucksack', 'sombrero', 'dolly girl beaker', 'cubic mug flock pink on brown', 'jardin etched glass cheese dish', 'hot baths soap holder', 'yellow pink flower design big bowl', 'large tahiti beach bag', 'marie antoinette trinket box gold', 'glass wine glass decorations', 'big pink poodle', 'round blue clock with sucker', 'doormat black flock', 'wood stocking christmas scandispot', 'opal white/silver flower necklace', 'small pink glass sundae dish', 'blue heart compact mirror', 'wooden frame antique white', 'doorknob cracked glaze ivory', 'hanging glass etched tealight', 'red retrospot jumbo bag', 'la palmiera tile hook', 'white dove honeycomb paper garland', 'midnight blue copper flower necklac', 'spaceboy tv dinner tray', 'flower blue clock with sucker', 'gold/m.o.p pendant orbit necklace', 'grass hopper wooden wall clock', 'pink round compact mirror', 'decoration , wobbly rabbit , metal', 'paper lantern 9 point holly star s', 'peace small wood letters', 'retro spot tea ceramic 11 pc', 'ruby glass cluster necklace', 'plasters in tin spaceboy', 'purple sweetheart bracelet', "retro plastic 70's tray", 'pearl & shell 42"neckl. green', 'pink polkadot wrap', 'ivory hanging decoration rabbit', '5 mini ice cream fridge magnets', 'enamel colander cream', 'acrylic jewel snowflake, pink', '2 ceramic christmas trees', 'letter "u" bling key ring', 'ninja rabbit pink', 'crystal large jewelled photo frame', 'cake stand victorian filigree large', 'pink daisy bag charm', 'angel on knees metal pole 100cm h', 'wire egg basket', 'wake up cockerel tile coaster', 'white tissue ream', 'christmas tree decoration with bell', 'small red retrospot mug in box', 'round white confetti in tube', 'vintage blue kitchen cabinet', 'green 3 tier glass plate stand', 'cognac aux oeufs metal 1 hook', 'money box first ade design', 'kitty pencil erasers', 'paper lantern 7 point snow star', 'blue/yellow ceramic candle holder', 'carrot charlie+lola coaster', '75 black fairy cake cases', 'gingham recipe book box', 'camouflage design teddy', 'home sweeet home 3 peg hanger', 'bread bin diner style black', 'pack 60 spaceboy cake cases', '4 napkin charms 3 keys', '12 vintage postcard']

# %% [markdown]
# ### transform into semantic vector embeddings using transformers

# %%
# # Load the pre-trained model and generate embeddings
# model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# embeddings = model.encode(unique_descriptions_list, show_progress_bar=True)

from transformers import GPT2Tokenizer, TFGPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = TFGPT2Model.from_pretrained('gpt2')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='tf')
output = model(encoded_input)

cosine_scores = util.cos_sim(embeddings, embeddings)
# Out:
# Batches:   0%|          | 0/163 [00:00<?, ?it/s]

# %%
# # Load the pre-trained model and generate embeddings
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
embeddings = model.encode(unique_descriptions_list, show_progress_bar=True)
# from transformers import BertTokenizer, TFBertModel
# tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
# model = TFBertModel.from_pretrained("bert-base-cased")
# inputs = tokenizer(unique_descriptions_list, return_tensors='tf', padding=True)
# model?
# outputs = model(inputs)
# embeddings = outputs.last_hidden_state
# sentence_embeddings = tf.reduce_mean(embeddings, axis=1)
cosine_scores = util.cos_sim(embeddings, embeddings)
# Out:
# Batches:   0%|          | 0/163 [00:00<?, ?it/s]

# %% [markdown]
# ### save cosine similarity values and embeddings

# %%
# print(cosine_scores.numpy())
print(embeddings)
with open("embeddings.npy", 'wb') as f:
    np.save(f, embeddings)
    print(embeddings.shape)
    
with open("embeddings_cosine_distance_matrix.npy", 'wb') as f:
    np.save(f, cosine_scores.numpy())
    print(cosine_scores.numpy().shape)
# Out:
# [[ 0.06141614  0.00574442 -0.04707118 ...  0.01002381  0.01709054
#   -0.02047717]
#  [ 0.03111615 -0.00370914 -0.02398733 ... -0.00128622 -0.0206185
#   -0.01568794]
#  [ 0.00723473  0.01887005 -0.00742267 ... -0.00205136  0.00849396
#    0.00802112]
#  ...
#  [ 0.04883057 -0.03688046 -0.03880781 ... -0.006199    0.00435512
#    0.04056031]
#  [-0.00331707  0.01234681  0.00349298 ...  0.02377513  0.01399172
#   -0.00972004]
#  [ 0.00380997  0.02309577 -0.00511046 ...  0.0244092   0.00478
#   -0.02809489]]
# (5211, 768)
# (5211, 5211)

# %%
from sklearn.decomposition import PCA
def make_pca_model(nc):
    pca = PCA(nc)
    pca.fit(embeddings)
    return pca

for ii in range(100,300):
    ipca = make_pca_model(ii)
    explained_variance = np.cumsum(ipca.explained_variance_ratio_)
    fig,ax = plt.subplots(figsize=(8,3))
    ax.bar(range(1, len(explained_variance) + 1), explained_variance, align='center')
    ax.set_title(f'nc: {ii}')
    if max(explained_variance) > 0.95:
        break

# %% [markdown]
# ### cluster product description embedding vectors with KMeans

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from hdbscan.validity import validity_index
from collections import Counter
import warnings

# warnings.filterwarnings('ignore')

X = embeddings
length = np.sqrt((X**2).sum(axis=1))[:,None]
X = X.astype('float64') / length
best_score = -np.inf
kept_res = None
for ii in tqdm(range(2,102)):
    mdl = KMeans(n_clusters=ii, tol=1e-6).fit(X)
    labels = mdl.labels_
    try:
        # scores = silhouette_score(X, labels)
        sample_scores = silhouette_samples(X, labels)
        scores = np.average(
            [np.median(sample_scores[labels==jj]) for jj in range(ii)],
            weights=[np.sum(labels==jj)/X.shape[0] for jj in range(ii)]
        )
        # all_group_sil_scores = []
        # for jj in range(ii):
            # frac = sum(labels==ii) / len(labels)
            # all_group_sil_scores.append(np.median(sample_scores[labels==jj]))
        # scores = np.median(all_group_sil_scores)
        if scores > best_score:
            kept_res = (ii, mdl, labels, scores)
            best_score = scores

    except:
        pass
    if (ii % 10) == 0 and kept_res:
        print(kept_res[0], best_score)
print(kept_res[0], kept_res[-1])
# Out:
#   9%|████████████                                                                                                                          | 9/100 [00:04<00:43,  2.10it/s]
# 10 0.03326691006492872
#  19%|█████████████████████████▎                                                                                                           | 19/100 [00:09<00:40,  2.01it/s]
# 20 0.049018881515937855
#  29%|██████████████████████████████████████▌                                                                                              | 29/100 [00:14<00:38,  1.85it/s]
# 25 0.05777196669829423
#  39%|███████████████████████████████████████████████████▊                                                                                 | 39/100 [00:19<00:33,  1.80it/s]
# 34 0.06785785153570278
#  49%|█████████████████████████████████████████████████████████████████▏                                                                   | 49/100 [00:26<00:33,  1.54it/s]
# 34 0.06785785153570278
#  59%|██████████████████████████████████████████████████████████████████████████████▍                                                      | 59/100 [00:33<00:27,  1.51it/s]
# 59 0.07108469964202138
#  69%|███████████████████████████████████████████████████████████████████████████████████████████▊                                         | 69/100 [00:40<00:22,  1.36it/s]
# 70 0.07535276313643775
#  79%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                            | 79/100 [00:47<00:14,  1.48it/s]
# 78 0.07733941071780123
#  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎              | 89/100 [00:54<00:08,  1.30it/s]
# 89 0.08071467781207463
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 99/100 [01:01<00:00,  1.52it/s]
# 89 0.08071467781207463
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:02<00:00,  1.61it/s]
# 89 0.08071467781207463

# %%
print(kept_res)
fig,axs = plt.subplots(figsize=(15,5),nrows=1)
axs.xaxis.get_majorticklocs()
histdata = axs.hist(kept_res[2], histtype='step', bins=np.arange(0,kept_res[0]+1,1))
# ax.clear()
lblcnts = Counter(kept_res[2])
ordered_cnts = [lblcnts[ii] for ii in range(kept_res[0])]
axs.bar(range(kept_res[0])+0.5*abs(np.diff(histdata[1][:2])), ordered_cnts, color='red', ec='black')
# Out:
# (89, KMeans(n_clusters=89, tol=1e-06), array([49, 12, 24, ..., 48, 18, 73], dtype=int32), 0.08071467781207463)
# <BarContainer object of 89 artists>

# %% [markdown]
# ### map these labels back onto the original datasets

# %%
product_group_id = [str(i) for i in kept_res[2]]
data = list(zip(unique_descriptions_list, product_group_id))
distinct_descriptions_df = spark.createDataFrame(data, ["description", "product_group_id"])

def map_cluster_ids(original_df, distinct_descriptions_df):
    # Join the original dataset with the distinct descriptions DataFrame on the description column
    mapped_df = original_df.join(distinct_descriptions_df, original_df.Description == distinct_descriptions_df.description, "left") \
                           .select(original_df["*"], distinct_descriptions_df["product_group_id"])
    
    return mapped_df

# Apply the function to map cluster IDs
s1clean = map_cluster_ids(s1clean, distinct_descriptions_df)

# Show the results
s1clean.show(truncate=False)
# Out:
# +-------+---------+-----------------------------------+--------+-------------------+-----+-----------+--------------+----------------+
# |Invoice|StockCode|Description                        |Quantity|InvoiceDate        |Price|Customer ID|Country       |product_group_id|
# +-------+---------+-----------------------------------+--------+-------------------+-----+-----------+--------------+----------------+
# |489572 |21538    |dairy maid pudding bowl            |2       |2009-12-01 13:29:00|3.75 |17611      |United Kingdom|49              |
# |489654 |70007    |hi tec alpine hand warmer          |4       |2009-12-01 17:19:00|1.65 |15750      |United Kingdom|2               |
# |489641 |84991    |60 teatime fairy cake cases        |24      |2009-12-01 16:18:00|0.55 |13819      |United Kingdom|75              |
# |489439 |21493    |vintage design gift tags           |12      |2009-12-01 09:28:00|0.85 |12682      |France        |43              |
# |489550 |22276    |wash bag vintage rose paisley      |6       |2009-12-01 12:33:00|2.55 |14156      |EIRE          |4               |
# |489682 |84568    |girls alphabet iron on patches     |288     |2009-12-02 10:08:00|0.21 |15759      |United Kingdom|84              |
# |489652 |21642    |assorted tutti frutti pen          |24      |2009-12-01 17:08:00|0.85 |15265      |United Kingdom|87              |
# |489787 |84007    |magic garden mount fuji            |2       |2009-12-02 11:53:00|2.55 |15542      |United Kingdom|77              |
# |489786 |90214S   |letter "s" bling key ring          |1       |2009-12-02 11:52:00|1.25 |17019      |United Kingdom|71              |
# |489766 |20761    |blue paisley sketchbook            |1       |2009-12-02 11:34:00|3.75 |17818      |United Kingdom|38              |
# |489556 |21491    |three vintage gift wraps           |6       |2009-12-01 12:47:00|1.95 |15719      |United Kingdom|55              |
# |489791 |21590    |kings choice cigar box matches     |1       |2009-12-02 12:06:00|1.25 |15542      |United Kingdom|8               |
# |489805 |20658    |red spotty luggage tag             |4       |2009-12-02 12:39:00|1.25 |17377      |United Kingdom|84              |
# |489800 |22356    |charlotte bag , pink/white spots   |2       |2009-12-02 12:26:00|0.85 |17768      |United Kingdom|84              |
# |489765 |22112    |chocolate hot water bottle         |2       |2009-12-02 11:33:00|4.95 |15353      |United Kingdom|2               |
# |489652 |84879    |assorted colour bird ornament      |8       |2009-12-01 17:08:00|1.69 |15265      |United Kingdom|5               |
# |489782 |20752    |retro blue spotty washing up gloves|3       |2009-12-02 11:45:00|2.1  |17189      |United Kingdom|84              |
# |489766 |21078    |20 strawberry paper napkins        |1       |2009-12-02 11:34:00|0.85 |17818      |United Kingdom|86              |
# |489675 |72023F   |red organic candle in glass        |96      |2009-12-02 09:47:00|0.85 |13777      |United Kingdom|85              |
# |489791 |85104    |silver glass t-light               |1       |2009-12-02 12:06:00|2.95 |15542      |United Kingdom|42              |
# +-------+---------+-----------------------------------+--------+-------------------+-----+-----------+--------------+----------------+
# only showing top 20 rows
